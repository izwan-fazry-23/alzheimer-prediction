# %%
import os
import mne
import pandas as pd
import warnings
import logging

# %%
# Configure logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# %%
warnings.filterwarnings("ignore", category=RuntimeWarning, message=".*boundary.*")

# %%
# Define input and output folder paths
input_folder = r"C:\Users\Izwan\Desktop\alzheimer-prediction\preprocessed-data"
output_folder = r"C:\Users\Izwan\Desktop\alzheimer-prediction\converted-files"

# %%
# Create output folder if it doesn't exist
os.makedirs(output_folder, exist_ok=True)

# %%
# Loop through all files in the input folder
for filename in os.listdir(input_folder):
    # Process only files with the .set extension
    if filename.endswith('.set'):
        # Construct the full path for the input file
        input_file_path = os.path.join(input_folder, filename)
        
        # Replace the .set extension with .csv for the output file name
        output_file_name = filename.replace('.set', '.csv')
        # Construct the full path for the output file
        output_file_path = os.path.join(output_folder, output_file_name)

        try:
            # Load the EEG data from the .set file using MNE
            raw = mne.io.read_raw_eeglab(input_file_path, preload=True)
            
            # Extract the data as a NumPy array (n_channels x n_times)
            data = raw.get_data()
            
            # Convert the data to a DataFrame with channels as column headers
            df = pd.DataFrame(data.T, columns=raw.ch_names)
            
            # Save the DataFrame to a CSV file, without adding an index column
            df.to_csv(output_file_path, index=False)
            
            # Log successful conversion
            logging.info(f"Successfully converted: {filename} to {output_file_name}")

        except Exception as e:
            # Log any errors that occur during the conversion process
            logging.error(f"Failed to convert {filename}: {e}")

# Log completion of the conversion process
logging.info(f"All files have been processed. Check '{output_folder}' for the results.")
# Out:
# 2025-01-08 11:28:17,076 - INFO - Successfully converted: sub-001_task-eyesclosed_eeg.set to sub-001_task-eyesclosed_eeg.csv
# 2025-01-08 11:28:29,966 - INFO - Successfully converted: sub-002_task-eyesclosed_eeg.set to sub-002_task-eyesclosed_eeg.csv
# 2025-01-08 11:28:34,971 - INFO - Successfully converted: sub-003_task-eyesclosed_eeg.set to sub-003_task-eyesclosed_eeg.csv
# 2025-01-08 11:28:46,906 - INFO - Successfully converted: sub-004_task-eyesclosed_eeg.set to sub-004_task-eyesclosed_eeg.csv
# 2025-01-08 11:29:02,129 - INFO - Successfully converted: sub-005_task-eyesclosed_eeg.set to sub-005_task-eyesclosed_eeg.csv
# 2025-01-08 11:29:13,174 - INFO - Successfully converted: sub-006_task-eyesclosed_eeg.set to sub-006_task-eyesclosed_eeg.csv
# 2025-01-08 11:29:25,748 - INFO - Successfully converted: sub-007_task-eyesclosed_eeg.set to sub-007_task-eyesclosed_eeg.csv
# 2025-01-08 11:29:38,718 - INFO - Successfully converted: sub-008_task-eyesclosed_eeg.set to sub-008_task-eyesclosed_eeg.csv
# 2025-01-08 11:29:48,762 - INFO - Successfully converted: sub-009_task-eyesclosed_eeg.set to sub-009_task-eyesclosed_eeg.csv
# 2025-01-08 11:30:10,549 - INFO - Successfully converted: sub-010_task-eyesclosed_eeg.set to sub-010_task-eyesclosed_eeg.csv
# 2025-01-08 11:30:23,413 - INFO - Successfully converted: sub-011_task-eyesclosed_eeg.set to sub-011_task-eyesclosed_eeg.csv
# 2025-01-08 11:30:37,926 - INFO - Successfully converted: sub-012_task-eyesclosed_eeg.set to sub-012_task-eyesclosed_eeg.csv
# 2025-01-08 11:30:52,282 - INFO - Successfully converted: sub-013_task-eyesclosed_eeg.set to sub-013_task-eyesclosed_eeg.csv
# 2025-01-08 11:31:07,982 - INFO - Successfully converted: sub-014_task-eyesclosed_eeg.set to sub-014_task-eyesclosed_eeg.csv
# 2025-01-08 11:31:23,053 - INFO - Successfully converted: sub-015_task-eyesclosed_eeg.set to sub-015_task-eyesclosed_eeg.csv
# 2025-01-08 11:31:39,161 - INFO - Successfully converted: sub-016_task-eyesclosed_eeg.set to sub-016_task-eyesclosed_eeg.csv
# 2025-01-08 11:31:52,928 - INFO - Successfully converted: sub-017_task-eyesclosed_eeg.set to sub-017_task-eyesclosed_eeg.csv
# 2025-01-08 11:32:06,945 - INFO - Successfully converted: sub-018_task-eyesclosed_eeg.set to sub-018_task-eyesclosed_eeg.csv
# 2025-01-08 11:32:22,567 - INFO - Successfully converted: sub-019_task-eyesclosed_eeg.set to sub-019_task-eyesclosed_eeg.csv
# 2025-01-08 11:32:36,878 - INFO - Successfully converted: sub-020_task-eyesclosed_eeg.set to sub-020_task-eyesclosed_eeg.csv
# 2025-01-08 11:32:52,046 - INFO - Successfully converted: sub-021_task-eyesclosed_eeg.set to sub-021_task-eyesclosed_eeg.csv
# 2025-01-08 11:33:05,516 - INFO - Successfully converted: sub-022_task-eyesclosed_eeg.set to sub-022_task-eyesclosed_eeg.csv
# 2025-01-08 11:33:19,764 - INFO - Successfully converted: sub-023_task-eyesclosed_eeg.set to sub-023_task-eyesclosed_eeg.csv
# 2025-01-08 11:33:32,850 - INFO - Successfully converted: sub-024_task-eyesclosed_eeg.set to sub-024_task-eyesclosed_eeg.csv
# 2025-01-08 11:33:44,684 - INFO - Successfully converted: sub-025_task-eyesclosed_eeg.set to sub-025_task-eyesclosed_eeg.csv
# 2025-01-08 11:33:59,960 - INFO - Successfully converted: sub-026_task-eyesclosed_eeg.set to sub-026_task-eyesclosed_eeg.csv
# 2025-01-08 11:34:14,078 - INFO - Successfully converted: sub-027_task-eyesclosed_eeg.set to sub-027_task-eyesclosed_eeg.csv
# 2025-01-08 11:34:29,096 - INFO - Successfully converted: sub-028_task-eyesclosed_eeg.set to sub-028_task-eyesclosed_eeg.csv
# 2025-01-08 11:34:41,915 - INFO - Successfully converted: sub-029_task-eyesclosed_eeg.set to sub-029_task-eyesclosed_eeg.csv
# 2025-01-08 11:34:51,525 - INFO - Successfully converted: sub-030_task-eyesclosed_eeg.set to sub-030_task-eyesclosed_eeg.csv
# 2025-01-08 11:35:11,060 - INFO - Successfully converted: sub-031_task-eyesclosed_eeg.set to sub-031_task-eyesclosed_eeg.csv
# 2025-01-08 11:35:24,337 - INFO - Successfully converted: sub-032_task-eyesclosed_eeg.set to sub-032_task-eyesclosed_eeg.csv
# 2025-01-08 11:35:36,890 - INFO - Successfully converted: sub-033_task-eyesclosed_eeg.set to sub-033_task-eyesclosed_eeg.csv
# 2025-01-08 11:35:53,224 - INFO - Successfully converted: sub-034_task-eyesclosed_eeg.set to sub-034_task-eyesclosed_eeg.csv
# 2025-01-08 11:36:05,596 - INFO - Successfully converted: sub-035_task-eyesclosed_eeg.set to sub-035_task-eyesclosed_eeg.csv
# 2025-01-08 11:36:19,877 - INFO - Successfully converted: sub-036_task-eyesclosed_eeg.set to sub-036_task-eyesclosed_eeg.csv
# 2025-01-08 11:36:33,154 - INFO - Successfully converted: sub-037_task-eyesclosed_eeg.set to sub-037_task-eyesclosed_eeg.csv
# 2025-01-08 11:36:49,477 - INFO - Successfully converted: sub-038_task-eyesclosed_eeg.set to sub-038_task-eyesclosed_eeg.csv
# 2025-01-08 11:37:03,856 - INFO - Successfully converted: sub-039_task-eyesclosed_eeg.set to sub-039_task-eyesclosed_eeg.csv
# 2025-01-08 11:37:20,232 - INFO - Successfully converted: sub-040_task-eyesclosed_eeg.set to sub-040_task-eyesclosed_eeg.csv
# 2025-01-08 11:37:34,998 - INFO - Successfully converted: sub-041_task-eyesclosed_eeg.set to sub-041_task-eyesclosed_eeg.csv
# 2025-01-08 11:37:51,598 - INFO - Successfully converted: sub-042_task-eyesclosed_eeg.set to sub-042_task-eyesclosed_eeg.csv
# 2025-01-08 11:38:05,360 - INFO - Successfully converted: sub-043_task-eyesclosed_eeg.set to sub-043_task-eyesclosed_eeg.csv
# 2025-01-08 11:38:20,092 - INFO - Successfully converted: sub-044_task-eyesclosed_eeg.set to sub-044_task-eyesclosed_eeg.csv
# 2025-01-08 11:38:34,592 - INFO - Successfully converted: sub-045_task-eyesclosed_eeg.set to sub-045_task-eyesclosed_eeg.csv
# 2025-01-08 11:38:47,242 - INFO - Successfully converted: sub-046_task-eyesclosed_eeg.set to sub-046_task-eyesclosed_eeg.csv
# 2025-01-08 11:39:01,582 - INFO - Successfully converted: sub-047_task-eyesclosed_eeg.set to sub-047_task-eyesclosed_eeg.csv
# 2025-01-08 11:39:18,319 - INFO - Successfully converted: sub-048_task-eyesclosed_eeg.set to sub-048_task-eyesclosed_eeg.csv
# 2025-01-08 11:39:31,391 - INFO - Successfully converted: sub-049_task-eyesclosed_eeg.set to sub-049_task-eyesclosed_eeg.csv
# 2025-01-08 11:39:45,284 - INFO - Successfully converted: sub-050_task-eyesclosed_eeg.set to sub-050_task-eyesclosed_eeg.csv
# 2025-01-08 11:39:58,619 - INFO - Successfully converted: sub-051_task-eyesclosed_eeg.set to sub-051_task-eyesclosed_eeg.csv
# 2025-01-08 11:40:11,785 - INFO - Successfully converted: sub-052_task-eyesclosed_eeg.set to sub-052_task-eyesclosed_eeg.csv
# 2025-01-08 11:40:25,271 - INFO - Successfully converted: sub-053_task-eyesclosed_eeg.set to sub-053_task-eyesclosed_eeg.csv
# 2025-01-08 11:40:39,732 - INFO - Successfully converted: sub-054_task-eyesclosed_eeg.set to sub-054_task-eyesclosed_eeg.csv
# 2025-01-08 11:40:53,714 - INFO - Successfully converted: sub-055_task-eyesclosed_eeg.set to sub-055_task-eyesclosed_eeg.csv
# 2025-01-08 11:41:07,625 - INFO - Successfully converted: sub-056_task-eyesclosed_eeg.set to sub-056_task-eyesclosed_eeg.csv
# 2025-01-08 11:41:21,359 - INFO - Successfully converted: sub-057_task-eyesclosed_eeg.set to sub-057_task-eyesclosed_eeg.csv
# 2025-01-08 11:41:34,723 - INFO - Successfully converted: sub-058_task-eyesclosed_eeg.set to sub-058_task-eyesclosed_eeg.csv
# 2025-01-08 11:41:48,146 - INFO - Successfully converted: sub-059_task-eyesclosed_eeg.set to sub-059_task-eyesclosed_eeg.csv
# 2025-01-08 11:42:00,912 - INFO - Successfully converted: sub-060_task-eyesclosed_eeg.set to sub-060_task-eyesclosed_eeg.csv
# 2025-01-08 11:42:15,360 - INFO - Successfully converted: sub-061_task-eyesclosed_eeg.set to sub-061_task-eyesclosed_eeg.csv
# 2025-01-08 11:42:30,759 - INFO - Successfully converted: sub-062_task-eyesclosed_eeg.set to sub-062_task-eyesclosed_eeg.csv
# 2025-01-08 11:42:44,358 - INFO - Successfully converted: sub-063_task-eyesclosed_eeg.set to sub-063_task-eyesclosed_eeg.csv
# 2025-01-08 11:42:58,930 - INFO - Successfully converted: sub-064_task-eyesclosed_eeg.set to sub-064_task-eyesclosed_eeg.csv
# 2025-01-08 11:43:14,225 - INFO - Successfully converted: sub-065_task-eyesclosed_eeg.set to sub-065_task-eyesclosed_eeg.csv
# 2025-01-08 11:43:23,745 - INFO - Successfully converted: sub-066_task-eyesclosed_eeg.set to sub-066_task-eyesclosed_eeg.csv
# 2025-01-08 11:43:35,182 - INFO - Successfully converted: sub-067_task-eyesclosed_eeg.set to sub-067_task-eyesclosed_eeg.csv
# 2025-01-08 11:43:45,147 - INFO - Successfully converted: sub-068_task-eyesclosed_eeg.set to sub-068_task-eyesclosed_eeg.csv
# 2025-01-08 11:43:55,704 - INFO - Successfully converted: sub-069_task-eyesclosed_eeg.set to sub-069_task-eyesclosed_eeg.csv
# 2025-01-08 11:44:03,876 - INFO - Successfully converted: sub-070_task-eyesclosed_eeg.set to sub-070_task-eyesclosed_eeg.csv
# 2025-01-08 11:44:14,628 - INFO - Successfully converted: sub-071_task-eyesclosed_eeg.set to sub-071_task-eyesclosed_eeg.csv
# 2025-01-08 11:44:26,385 - INFO - Successfully converted: sub-072_task-eyesclosed_eeg.set to sub-072_task-eyesclosed_eeg.csv
# 2025-01-08 11:44:41,014 - INFO - Successfully converted: sub-073_task-eyesclosed_eeg.set to sub-073_task-eyesclosed_eeg.csv
# 2025-01-08 11:44:58,187 - INFO - Successfully converted: sub-074_task-eyesclosed_eeg.set to sub-074_task-eyesclosed_eeg.csv
# 2025-01-08 11:45:11,188 - INFO - Successfully converted: sub-075_task-eyesclosed_eeg.set to sub-075_task-eyesclosed_eeg.csv
# 2025-01-08 11:45:25,477 - INFO - Successfully converted: sub-076_task-eyesclosed_eeg.set to sub-076_task-eyesclosed_eeg.csv
# 2025-01-08 11:45:37,862 - INFO - Successfully converted: sub-077_task-eyesclosed_eeg.set to sub-077_task-eyesclosed_eeg.csv
# 2025-01-08 11:45:52,693 - INFO - Successfully converted: sub-078_task-eyesclosed_eeg.set to sub-078_task-eyesclosed_eeg.csv
# 2025-01-08 11:46:06,945 - INFO - Successfully converted: sub-079_task-eyesclosed_eeg.set to sub-079_task-eyesclosed_eeg.csv
# 2025-01-08 11:46:22,808 - INFO - Successfully converted: sub-080_task-eyesclosed_eeg.set to sub-080_task-eyesclosed_eeg.csv
# 2025-01-08 11:46:37,494 - INFO - Successfully converted: sub-081_task-eyesclosed_eeg.set to sub-081_task-eyesclosed_eeg.csv
# 2025-01-08 11:46:50,823 - INFO - Successfully converted: sub-082_task-eyesclosed_eeg.set to sub-082_task-eyesclosed_eeg.csv
# 2025-01-08 11:47:06,607 - INFO - Successfully converted: sub-083_task-eyesclosed_eeg.set to sub-083_task-eyesclosed_eeg.csv
# 2025-01-08 11:47:18,189 - INFO - Successfully converted: sub-084_task-eyesclosed_eeg.set to sub-084_task-eyesclosed_eeg.csv
# 2025-01-08 11:47:28,156 - INFO - Successfully converted: sub-085_task-eyesclosed_eeg.set to sub-085_task-eyesclosed_eeg.csv
# 2025-01-08 11:47:38,326 - INFO - Successfully converted: sub-086_task-eyesclosed_eeg.set to sub-086_task-eyesclosed_eeg.csv
# 2025-01-08 11:47:48,958 - INFO - Successfully converted: sub-087_task-eyesclosed_eeg.set to sub-087_task-eyesclosed_eeg.csv
# 2025-01-08 11:48:02,390 - INFO - Successfully converted: sub-088_task-eyesclosed_eeg.set to sub-088_task-eyesclosed_eeg.csv
# 2025-01-08 11:48:02,391 - INFO - All files have been processed. Check 'C:\Users\Izwan\Desktop\alzheimer-prediction\converted-files' for the results.
