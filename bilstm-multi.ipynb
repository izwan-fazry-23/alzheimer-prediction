# %%
# Import necessary libraries
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, roc_auc_score, auc, roc_curve, confusion_matrix
from torch.utils.data import DataLoader, TensorDataset

# %%
# Check if GPU is available
if torch.cuda.is_available():
    device = torch.device("cuda")
    print("Using GPU")
else:
    device = torch.device("cpu")
    print("Using CPU")
# Out:
# Using GPU

# %%
# Load the EEG features
df = pd.read_csv(r"C:\Users\Izwan\Desktop\alzheimer-prediction\code\1-feature-extraction\extracted-features-All_Subjects-DWT3-3s.csv")

# %%
# Sort the data by subject and epoch to maintain chronological order
df = df.sort_values(by=['subject', 'epoch'])

# Splitting the data chronologically
num_epochs_per_subject = df['epoch'].max()
train_split = int(num_epochs_per_subject * 0.7)  # 70% of the epochs for training
val_split = int(num_epochs_per_subject * 0.85)  # 15% for validation, remaining 15% for testing

# %%
# Initialize lists to store the splits
train_indices, val_indices, test_indices = [], [], []

# Split data for each subject
subjects = df['subject'].unique()
for subj in subjects:
    subj_df = df[df['subject'] == subj]
    
    # Append indices to the respective lists
    train_indices.extend(subj_df.iloc[:train_split].index)
    val_indices.extend(subj_df.iloc[train_split:val_split].index)
    test_indices.extend(subj_df.iloc[val_split:].index)

# Creating DataFrames for each split
train_df = df.loc[train_indices]
val_df = df.loc[val_indices]
test_df = df.loc[test_indices]

# Ensure proper encoding of target variable
X_train = train_df.drop(['epoch', 'subject', 'gender', 'class', 'mmse'], axis=1)
X_val = val_df.drop(['epoch', 'subject', 'gender', 'class', 'mmse'], axis=1)
X_test = test_df.drop(['epoch', 'subject', 'gender', 'class', 'mmse'], axis=1)

label_mapping = {'A': 0, 'C': 1, 'F': 2}
y_train = train_df['class'].map(label_mapping).values
y_val = val_df['class'].map(label_mapping).values
y_test = test_df['class'].map(label_mapping).values

# %%
# Check subject epochs in each set
print("Train Set Summary:")
print(train_df.groupby('subject')['epoch'].agg(['min', 'max', 'count']))

print("\nValidation Set Summary:")
print(val_df.groupby('subject')['epoch'].agg(['min', 'max', 'count']))

print("\nTest Set Summary:")
print(test_df.groupby('subject')['epoch'].agg(['min', 'max', 'count']))
# Out:
# Train Set Summary:
#          min  max  count
# subject
# sub-001    1   71     71
# sub-002    1   71     71
# sub-003    1   71     71
# sub-004    1   71     71
# sub-005    1   71     71
# ...      ...  ...    ...
# sub-084    1   71     71
# sub-085    1   71     71
# sub-086    1   71     71
# sub-087    1   71     71
# sub-088    1   71     71
#
# [88 rows x 3 columns]
#
# Validation Set Summary:
#          min  max  count
# subject
# sub-001   72   86     15
# sub-002   72   86     15
# sub-003   72   86     15
# sub-004   72   86     15
# sub-005   72   86     15
# ...      ...  ...    ...
# sub-084   72   86     15
# sub-085   72   86     15
# sub-086   72   86     15
# sub-087   72   86     15
# sub-088   72   86     15
#
# [88 rows x 3 columns]
#
# Test Set Summary:
#          min  max  count
# subject
# sub-001   87  102     16
# sub-002   87  102     16
# sub-003   87  102     16
# sub-004   87  102     16
# sub-005   87  102     16
# ...      ...  ...    ...
# sub-084   87  102     16
# sub-085   87  102     16
# sub-086   87  102     16
# sub-087   87  102     16
# sub-088   87  102     16
#
# [88 rows x 3 columns]

# %%
# Standardize the data
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# Convert data to tensors
X_train = torch.tensor(X_train, dtype=torch.float32).unsqueeze(1).to(device)
X_val = torch.tensor(X_val, dtype=torch.float32).unsqueeze(1).to(device)
X_test = torch.tensor(X_test, dtype=torch.float32).unsqueeze(1).to(device)
y_train = torch.tensor(y_train, dtype=torch.long).to(device)
y_val = torch.tensor(y_val, dtype=torch.long).to(device)
y_test = torch.tensor(y_test, dtype=torch.long).to(device)

# Create DataLoaders
batch_size = 64
train_loader = DataLoader(TensorDataset(X_train, y_train), batch_size=batch_size, shuffle=True)
val_loader = DataLoader(TensorDataset(X_val, y_val), batch_size=batch_size, shuffle=False)
test_loader = DataLoader(TensorDataset(X_test, y_test), batch_size=batch_size, shuffle=False)

# %%
# Define the Bi-LSTM model for multi-class classification
class BiLSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size_1, hidden_size_2, output_size):
        super(BiLSTMModel, self).__init__()
        # Define bidirectional LSTM layers
        self.lstm1 = nn.LSTM(input_size, hidden_size_1, batch_first=True, bidirectional=True)
        self.dropout1 = nn.Dropout(0.2)  # Dropout after the first LSTM layer
        self.lstm2 = nn.LSTM(hidden_size_1 * 2, hidden_size_2, batch_first=True, bidirectional=True)
        self.dropout2 = nn.Dropout(0.2)  # Dropout after the second LSTM layer
        # Adjust the fully connected layer input size to match the bidirectional LSTM output
        self.fc = nn.Linear(hidden_size_2 * 2, output_size)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x, _ = self.lstm1(x)
        x = self.dropout1(x)  # Apply Dropout1
        x, _ = self.lstm2(x)
        x = self.dropout2(x)  # Apply Dropout2
        x = x[:, -1, :]  # Use the last time step's output
        x = self.fc(x)
        x = self.softmax(x)  # Apply Softmax for probabilities
        return x

# %%
# Model, criterion, optimizer setup
input_size = X_train.shape[2]
hidden_size_1 = 64
hidden_size_2 = 8
output_size = 3  # Three classes: 'A', 'C', 'F'

model = BiLSTMModel(input_size, hidden_size_1, hidden_size_2, output_size).to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)

# %%
# Train the model
epochs = 100
train_losses, val_losses = [], []
train_accuracies, val_accuracies = [], []

for epoch in range(epochs):
    # Training phase
    model.train()
    epoch_loss = 0
    correct_train = 0
    total_train = 0
    for X_batch, y_batch in train_loader:
        optimizer.zero_grad()
        outputs = model(X_batch)
        loss = criterion(outputs, y_batch)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        
        # Calculate training accuracy
        _, predicted = torch.max(outputs.data, 1)
        total_train += y_batch.size(0)
        correct_train += (predicted == y_batch).sum().item()
    
    train_losses.append(epoch_loss / len(train_loader))
    train_accuracy = 100 * correct_train / total_train
    train_accuracies.append(train_accuracy)

    # Validation phase
    model.eval()
    val_loss = 0
    correct_val = 0
    total_val = 0
    with torch.no_grad():
        for X_batch, y_batch in val_loader:
            outputs = model(X_batch)
            loss = criterion(outputs, y_batch)
            val_loss += loss.item()
            
            # Calculate validation accuracy
            _, predicted = torch.max(outputs.data, 1)
            total_val += y_batch.size(0)
            correct_val += (predicted == y_batch).sum().item()
    
    val_losses.append(val_loss / len(val_loader))
    val_accuracy = 100 * correct_val / total_val
    val_accuracies.append(val_accuracy)
    
    print(f"Epoch {epoch+1}/{epochs}, Training Loss: {train_losses[-1]:.4f}, Validation Loss: {val_losses[-1]:.4f}, Training Accuracy: {train_accuracy:.2f}%, Validation Accuracy: {val_accuracy:.2f}%")
# Out:
# Epoch 1/100, Training Loss: 1.0567, Validation Loss: 0.9845, Training Accuracy: 49.18%, Validation Accuracy: 59.55%
# Epoch 2/100, Training Loss: 0.9390, Validation Loss: 0.8961, Training Accuracy: 63.19%, Validation Accuracy: 65.76%
# Epoch 3/100, Training Loss: 0.8671, Validation Loss: 0.8444, Training Accuracy: 69.77%, Validation Accuracy: 70.76%
# Epoch 4/100, Training Loss: 0.8210, Validation Loss: 0.8204, Training Accuracy: 73.93%, Validation Accuracy: 73.41%
# Epoch 5/100, Training Loss: 0.7924, Validation Loss: 0.8061, Training Accuracy: 76.73%, Validation Accuracy: 74.17%
# Epoch 6/100, Training Loss: 0.7714, Validation Loss: 0.7974, Training Accuracy: 78.83%, Validation Accuracy: 75.53%
# Epoch 7/100, Training Loss: 0.7518, Validation Loss: 0.7878, Training Accuracy: 80.81%, Validation Accuracy: 75.53%
# Epoch 8/100, Training Loss: 0.7425, Validation Loss: 0.7732, Training Accuracy: 81.48%, Validation Accuracy: 78.03%
# Epoch 9/100, Training Loss: 0.7217, Validation Loss: 0.7719, Training Accuracy: 83.66%, Validation Accuracy: 76.89%
# Epoch 10/100, Training Loss: 0.7094, Validation Loss: 0.7637, Training Accuracy: 85.07%, Validation Accuracy: 78.11%
# Epoch 11/100, Training Loss: 0.6986, Validation Loss: 0.7558, Training Accuracy: 85.84%, Validation Accuracy: 79.09%
# Epoch 12/100, Training Loss: 0.6924, Validation Loss: 0.7589, Training Accuracy: 86.48%, Validation Accuracy: 79.17%
# Epoch 13/100, Training Loss: 0.6876, Validation Loss: 0.7638, Training Accuracy: 86.96%, Validation Accuracy: 78.79%
# Epoch 14/100, Training Loss: 0.6784, Validation Loss: 0.7604, Training Accuracy: 87.90%, Validation Accuracy: 78.79%
# Epoch 15/100, Training Loss: 0.6659, Validation Loss: 0.7469, Training Accuracy: 89.26%, Validation Accuracy: 80.00%
# Epoch 16/100, Training Loss: 0.6642, Validation Loss: 0.7520, Training Accuracy: 89.24%, Validation Accuracy: 79.02%
# Epoch 17/100, Training Loss: 0.6589, Validation Loss: 0.7532, Training Accuracy: 89.64%, Validation Accuracy: 78.94%
# Epoch 18/100, Training Loss: 0.6545, Validation Loss: 0.7566, Training Accuracy: 90.41%, Validation Accuracy: 79.24%
# Epoch 19/100, Training Loss: 0.6462, Validation Loss: 0.7514, Training Accuracy: 91.39%, Validation Accuracy: 79.32%
# Epoch 20/100, Training Loss: 0.6484, Validation Loss: 0.7659, Training Accuracy: 90.62%, Validation Accuracy: 77.73%
# Epoch 21/100, Training Loss: 0.6437, Validation Loss: 0.7420, Training Accuracy: 91.23%, Validation Accuracy: 80.00%
# Epoch 22/100, Training Loss: 0.6374, Validation Loss: 0.7430, Training Accuracy: 91.95%, Validation Accuracy: 80.30%
# Epoch 23/100, Training Loss: 0.6390, Validation Loss: 0.7448, Training Accuracy: 91.60%, Validation Accuracy: 79.92%
# Epoch 24/100, Training Loss: 0.6318, Validation Loss: 0.7421, Training Accuracy: 92.29%, Validation Accuracy: 80.00%
# Epoch 25/100, Training Loss: 0.6307, Validation Loss: 0.7385, Training Accuracy: 92.43%, Validation Accuracy: 81.06%
# Epoch 26/100, Training Loss: 0.6293, Validation Loss: 0.7325, Training Accuracy: 92.69%, Validation Accuracy: 81.67%
# Epoch 27/100, Training Loss: 0.6272, Validation Loss: 0.7390, Training Accuracy: 92.62%, Validation Accuracy: 80.76%
# Epoch 28/100, Training Loss: 0.6234, Validation Loss: 0.7421, Training Accuracy: 93.17%, Validation Accuracy: 80.15%
# Epoch 29/100, Training Loss: 0.6206, Validation Loss: 0.7394, Training Accuracy: 93.58%, Validation Accuracy: 80.91%
# Epoch 30/100, Training Loss: 0.6218, Validation Loss: 0.7586, Training Accuracy: 93.39%, Validation Accuracy: 78.26%
# Epoch 31/100, Training Loss: 0.6177, Validation Loss: 0.7397, Training Accuracy: 93.65%, Validation Accuracy: 80.68%
# Epoch 32/100, Training Loss: 0.6165, Validation Loss: 0.7344, Training Accuracy: 93.97%, Validation Accuracy: 81.44%
# Epoch 33/100, Training Loss: 0.6163, Validation Loss: 0.7398, Training Accuracy: 93.73%, Validation Accuracy: 80.83%
# Epoch 34/100, Training Loss: 0.6183, Validation Loss: 0.7364, Training Accuracy: 93.68%, Validation Accuracy: 80.83%
# Epoch 35/100, Training Loss: 0.6150, Validation Loss: 0.7416, Training Accuracy: 94.09%, Validation Accuracy: 80.15%
# Epoch 36/100, Training Loss: 0.6126, Validation Loss: 0.7277, Training Accuracy: 94.45%, Validation Accuracy: 82.27%
# Epoch 37/100, Training Loss: 0.6104, Validation Loss: 0.7366, Training Accuracy: 94.25%, Validation Accuracy: 80.68%
# Epoch 38/100, Training Loss: 0.6107, Validation Loss: 0.7400, Training Accuracy: 94.43%, Validation Accuracy: 80.45%
# Epoch 39/100, Training Loss: 0.6116, Validation Loss: 0.7310, Training Accuracy: 94.30%, Validation Accuracy: 81.67%
# Epoch 40/100, Training Loss: 0.6084, Validation Loss: 0.7322, Training Accuracy: 94.41%, Validation Accuracy: 81.74%
# Epoch 41/100, Training Loss: 0.6083, Validation Loss: 0.7272, Training Accuracy: 94.40%, Validation Accuracy: 81.82%
# Epoch 42/100, Training Loss: 0.6052, Validation Loss: 0.7397, Training Accuracy: 94.93%, Validation Accuracy: 80.38%
# Epoch 43/100, Training Loss: 0.6075, Validation Loss: 0.7313, Training Accuracy: 94.62%, Validation Accuracy: 82.27%
# Epoch 44/100, Training Loss: 0.6093, Validation Loss: 0.7518, Training Accuracy: 94.51%, Validation Accuracy: 79.17%
# Epoch 45/100, Training Loss: 0.6043, Validation Loss: 0.7431, Training Accuracy: 94.99%, Validation Accuracy: 80.23%
# Epoch 46/100, Training Loss: 0.6045, Validation Loss: 0.7341, Training Accuracy: 95.01%, Validation Accuracy: 81.44%
# Epoch 47/100, Training Loss: 0.6039, Validation Loss: 0.7325, Training Accuracy: 95.13%, Validation Accuracy: 81.29%
# Epoch 48/100, Training Loss: 0.6008, Validation Loss: 0.7390, Training Accuracy: 95.26%, Validation Accuracy: 80.83%
# Epoch 49/100, Training Loss: 0.6025, Validation Loss: 0.7417, Training Accuracy: 95.10%, Validation Accuracy: 80.23%
# Epoch 50/100, Training Loss: 0.6036, Validation Loss: 0.7382, Training Accuracy: 95.15%, Validation Accuracy: 80.91%
# Epoch 51/100, Training Loss: 0.6007, Validation Loss: 0.7332, Training Accuracy: 95.36%, Validation Accuracy: 81.21%
# Epoch 52/100, Training Loss: 0.6014, Validation Loss: 0.7313, Training Accuracy: 95.10%, Validation Accuracy: 81.82%
# Epoch 53/100, Training Loss: 0.6034, Validation Loss: 0.7417, Training Accuracy: 95.04%, Validation Accuracy: 79.92%
# Epoch 54/100, Training Loss: 0.5995, Validation Loss: 0.7476, Training Accuracy: 95.50%, Validation Accuracy: 79.47%
# Epoch 55/100, Training Loss: 0.6019, Validation Loss: 0.7384, Training Accuracy: 95.31%, Validation Accuracy: 80.38%
# Epoch 56/100, Training Loss: 0.6020, Validation Loss: 0.7420, Training Accuracy: 95.12%, Validation Accuracy: 80.68%
# Epoch 57/100, Training Loss: 0.6035, Validation Loss: 0.7482, Training Accuracy: 95.07%, Validation Accuracy: 79.85%
# Epoch 58/100, Training Loss: 0.5990, Validation Loss: 0.7300, Training Accuracy: 95.50%, Validation Accuracy: 82.05%
# Epoch 59/100, Training Loss: 0.5960, Validation Loss: 0.7429, Training Accuracy: 95.89%, Validation Accuracy: 80.61%
# Epoch 60/100, Training Loss: 0.5998, Validation Loss: 0.7306, Training Accuracy: 95.34%, Validation Accuracy: 81.89%
# Epoch 61/100, Training Loss: 0.6010, Validation Loss: 0.7282, Training Accuracy: 95.18%, Validation Accuracy: 82.12%
# Epoch 62/100, Training Loss: 0.5965, Validation Loss: 0.7422, Training Accuracy: 95.76%, Validation Accuracy: 80.00%
# Epoch 63/100, Training Loss: 0.5934, Validation Loss: 0.7433, Training Accuracy: 95.98%, Validation Accuracy: 79.92%
# Epoch 64/100, Training Loss: 0.5953, Validation Loss: 0.7511, Training Accuracy: 95.92%, Validation Accuracy: 79.47%
# Epoch 65/100, Training Loss: 0.5930, Validation Loss: 0.7322, Training Accuracy: 96.19%, Validation Accuracy: 81.59%
# Epoch 66/100, Training Loss: 0.5931, Validation Loss: 0.7306, Training Accuracy: 96.05%, Validation Accuracy: 81.29%
# Epoch 67/100, Training Loss: 0.5934, Validation Loss: 0.7326, Training Accuracy: 95.98%, Validation Accuracy: 81.36%
# Epoch 68/100, Training Loss: 0.5926, Validation Loss: 0.7261, Training Accuracy: 96.16%, Validation Accuracy: 81.82%
# Epoch 69/100, Training Loss: 0.5971, Validation Loss: 0.7375, Training Accuracy: 95.61%, Validation Accuracy: 80.98%
# Epoch 70/100, Training Loss: 0.5969, Validation Loss: 0.7303, Training Accuracy: 95.73%, Validation Accuracy: 81.97%
# Epoch 71/100, Training Loss: 0.5960, Validation Loss: 0.7324, Training Accuracy: 95.76%, Validation Accuracy: 81.36%
# Epoch 72/100, Training Loss: 0.5958, Validation Loss: 0.7270, Training Accuracy: 95.84%, Validation Accuracy: 82.20%
# Epoch 73/100, Training Loss: 0.5972, Validation Loss: 0.7495, Training Accuracy: 95.57%, Validation Accuracy: 79.24%
# Epoch 74/100, Training Loss: 0.5948, Validation Loss: 0.7337, Training Accuracy: 95.84%, Validation Accuracy: 81.06%
# Epoch 75/100, Training Loss: 0.5933, Validation Loss: 0.7317, Training Accuracy: 96.05%, Validation Accuracy: 81.06%
# Epoch 76/100, Training Loss: 0.5929, Validation Loss: 0.7329, Training Accuracy: 96.06%, Validation Accuracy: 80.98%
# Epoch 77/100, Training Loss: 0.5927, Validation Loss: 0.7327, Training Accuracy: 96.14%, Validation Accuracy: 81.29%
# Epoch 78/100, Training Loss: 0.5966, Validation Loss: 0.7468, Training Accuracy: 95.77%, Validation Accuracy: 79.47%
# Epoch 79/100, Training Loss: 0.5933, Validation Loss: 0.7302, Training Accuracy: 96.09%, Validation Accuracy: 81.82%
# Epoch 80/100, Training Loss: 0.5955, Validation Loss: 0.7425, Training Accuracy: 95.84%, Validation Accuracy: 79.77%
# Epoch 81/100, Training Loss: 0.5982, Validation Loss: 0.7312, Training Accuracy: 95.50%, Validation Accuracy: 82.05%
# Epoch 82/100, Training Loss: 0.5897, Validation Loss: 0.7394, Training Accuracy: 96.37%, Validation Accuracy: 80.68%
# Epoch 83/100, Training Loss: 0.5950, Validation Loss: 0.7328, Training Accuracy: 95.87%, Validation Accuracy: 81.44%
# Epoch 84/100, Training Loss: 0.5947, Validation Loss: 0.7324, Training Accuracy: 95.89%, Validation Accuracy: 81.74%
# Epoch 85/100, Training Loss: 0.5928, Validation Loss: 0.7255, Training Accuracy: 95.97%, Validation Accuracy: 82.12%
# Epoch 86/100, Training Loss: 0.5944, Validation Loss: 0.7235, Training Accuracy: 96.01%, Validation Accuracy: 82.27%
# Epoch 87/100, Training Loss: 0.5924, Validation Loss: 0.7238, Training Accuracy: 96.05%, Validation Accuracy: 82.73%
# Epoch 88/100, Training Loss: 0.5931, Validation Loss: 0.7356, Training Accuracy: 95.93%, Validation Accuracy: 81.06%
# Epoch 89/100, Training Loss: 0.5920, Validation Loss: 0.7383, Training Accuracy: 96.27%, Validation Accuracy: 80.68%
# Epoch 90/100, Training Loss: 0.5931, Validation Loss: 0.7366, Training Accuracy: 95.98%, Validation Accuracy: 81.14%
# Epoch 91/100, Training Loss: 0.5915, Validation Loss: 0.7319, Training Accuracy: 96.27%, Validation Accuracy: 81.44%
# Epoch 92/100, Training Loss: 0.5929, Validation Loss: 0.7266, Training Accuracy: 96.11%, Validation Accuracy: 82.42%
# Epoch 93/100, Training Loss: 0.5925, Validation Loss: 0.7385, Training Accuracy: 96.19%, Validation Accuracy: 80.30%
# Epoch 94/100, Training Loss: 0.5929, Validation Loss: 0.7341, Training Accuracy: 96.08%, Validation Accuracy: 81.21%
# Epoch 95/100, Training Loss: 0.5922, Validation Loss: 0.7285, Training Accuracy: 96.11%, Validation Accuracy: 81.59%
# Epoch 96/100, Training Loss: 0.5897, Validation Loss: 0.7246, Training Accuracy: 96.27%, Validation Accuracy: 82.12%
# Epoch 97/100, Training Loss: 0.5935, Validation Loss: 0.7328, Training Accuracy: 95.95%, Validation Accuracy: 81.44%
# Epoch 98/100, Training Loss: 0.5896, Validation Loss: 0.7248, Training Accuracy: 96.38%, Validation Accuracy: 82.12%
# Epoch 99/100, Training Loss: 0.5935, Validation Loss: 0.7352, Training Accuracy: 95.97%, Validation Accuracy: 81.36%
# Epoch 100/100, Training Loss: 0.5916, Validation Loss: 0.7337, Training Accuracy: 96.03%, Validation Accuracy: 80.38%

# %%
# Plotting the loss curve
plt.figure()
plt.plot(range(1, epochs + 1), train_losses, label='Training Loss', color='blue')
plt.plot(range(1, epochs + 1), val_losses, label='Validation Loss', color='purple')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Bi-LSTM Loss (Multi-Class)')
plt.legend()
plt.show()

# %%
# Evaluate the model
model.eval()
y_pred_prob, y_pred = [], []
with torch.no_grad():
    for X_batch, _ in test_loader:
        outputs = model(X_batch).squeeze()
        y_pred_prob.extend(outputs.tolist())  # Collect probabilities for all classes
        y_pred.extend(torch.argmax(outputs, dim=1).tolist())  # Collect predicted classes

# Convert predictions and true labels to CPU for metric calculation
y_test_cpu = y_test.cpu()
y_pred_cpu = torch.tensor(y_pred).cpu()

# Generate and print the classification report
target_names = ['Alzheimer', 'Healthy', 'FTD']
print("Classification Report:")
print(classification_report(y_test_cpu, y_pred_cpu, target_names=target_names))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#    Alzheimer       0.81      0.79      0.80       576
#      Healthy       0.78      0.89      0.83       464
#          FTD       0.79      0.68      0.73       368
#
#     accuracy                           0.80      1408
#    macro avg       0.79      0.79      0.79      1408
# weighted avg       0.80      0.80      0.79      1408

# %%
# Define colors for each class
colors = ['blue', 'purple', 'darkblue'] 

# Compute ROC curve and AUC for each class
y_test_onehot = torch.nn.functional.one_hot(y_test_cpu, num_classes=3).numpy()
y_pred_prob_array = torch.tensor(y_pred_prob).cpu().numpy()

plt.figure()
for i, class_name in enumerate(target_names):
    fpr, tpr, _ = roc_curve(y_test_onehot[:, i], y_pred_prob_array[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, color=colors[i], lw=2, label=f'{class_name} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], color='black', lw=2, linestyle='--')  # Diagonal line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve for BiLSTM (Multi-Class)')
plt.legend(loc="lower right")
plt.show()

# %%
# Compute confusion matrix
conf_matrix = confusion_matrix(y_test_cpu, y_pred_cpu)

# Plot confusion matrix
plt.figure()
sns.heatmap(conf_matrix, cmap='Blues', annot=True, fmt='d', annot_kws={"size": 14}, cbar=False)
plt.xlabel('Predicted Labels', fontsize=14)
plt.ylabel('Actual Labels', fontsize=14)
plt.title('Confusion Matrix for Bi-LSTM (Multi-Class)', fontsize=16)
plt.xticks(ticks=[0.5, 1.5, 2.5], labels=target_names, fontsize=12)
plt.yticks(ticks=[0.5, 1.5, 2.5], labels=target_names, fontsize=12, rotation=0)
plt.tight_layout()

# Display the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
plt.show()
# Out:
# Confusion Matrix:
# [[457  75  44]
#  [ 28 411  25]
#  [ 77  39 252]]
